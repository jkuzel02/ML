# %%
import requests
import pandas as pd

method = "GET"
url = "https://boardgamegeek.com/xmlapi2/thing"
params = {"id": 174430}
headers = {"Authentication": "Bearer 113797ef-dfd9-402f-b409-d79174b53288"}

r = requests.Request(
    method,
    url, 
    params
)
r.prepare(headers=headers)

s = requests.Session()

s.send(r)
s
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[25], line 14
#       7 headers = {"Authentication": "Bearer 113797ef-dfd9-402f-b409-d79174b53288"}
#       9 r = requests.Request(
#      10     method,
#      11     url,
#      12     params
#      13 )
# ---> 14 r.prepare(headers=headers)
#      16 s = requests.Session()
#      18 s.send(r)
#
# TypeError: Request.prepare() got an unexpected keyword argument 'headers'
